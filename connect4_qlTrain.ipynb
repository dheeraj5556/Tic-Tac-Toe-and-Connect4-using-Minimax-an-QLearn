# %%
import numpy as np
import random
import pickle

def gameBoard(rows=6, columns=7):
    return np.zeros((rows, columns))

def isLegal(board, column):
    return board[len(board)-1][column] == 0

def availableRow(board, column):
    return next((row for row in range(len(board)) if board[row][column] == 0), None)

def legalMove(board):
    return [column for column in range(board.shape[1]) if isLegal(board, column)]


    
def findAvailablePosition(board, marker):
    rows, cols = board.shape
    for row, row_vals in enumerate(board):
        for col, col_val in enumerate(row_vals[:-3]):
            if all(elem == marker for elem in row_vals[col:col+4]):
                return row, col
        for col, col_vals in zip(range(cols), (board[r][col] for r in range(row, min(row+4, rows)))):
            if all(elem == marker for elem in col_vals):
                return row, col
        for col, col_vals in enumerate(row_vals[:-3]):
            if row < rows-3 and col < cols-3:
                diag_vals = [board[row+i][col+i] for i in range(4)]
                if all(elem == marker for elem in diag_vals):
                    return row, col
        for col, col_vals in enumerate(row_vals[:-3]):
            if row >= 3 and col < cols-3:
                diag_vals = [board[row-i][col+i] for i in range(4)]
                if all(elem == marker for elem in diag_vals):
                    return row, col
    else:
        return -1, -1

def checkWin(board, marker):
    rows, cols = board.shape
    for row in range(rows):
        for col in range(cols - 3):
            if all(board[row][col + i] == marker for i in range(4)):
                return True

    for row in range(rows - 3):
        for col in range(cols):
            if all(board[row + i][col] == marker for i in range(4)):
                return True

    for row in range(rows - 3):
        for col in range(cols - 3):
            if all(board[row + i][col + i] == marker for i in range(4)):
                return True

    for row in range(3, rows):
        for col in range(cols - 3):
            if all(board[row - i][col + i] == marker for i in range(4)):
                return True

    return False


def isFinLegal(board, defaultmark, minmaxmark):
    return any(checkWin(board, marker) for marker in (defaultmark, minmaxmark)) or not legalMove(board)

def defaultPlayerMove(gamess, board, defaultmark, minmaxmark):
    if isFinLegal(board, defaultmark, minmaxmark):
        defaultrow, defaultcol = findAvailablePosition(board, defaultmark)
        if defaultrow != -1:
            return defaultrow, defaultcol
        else:
            mmrow, mmcol = findAvailablePosition(board, minmaxmark)
            if mmrow != -1:
                return mmrow, mmcol
            else:
                availablemoves = legalMove(board)
                randrow = availableRow(board, random.choice(availablemoves))
                randcol = random.choice(availablemoves)
                return randrow, randcol
    else:
        availablemoves = legalMove(board)
        randrow = availableRow(board, random.choice(availablemoves)) 
        randcol = random.choice(availablemoves)

        return randrow, randcol

def findPos(positions):
    return int(''.join([str(int(position)) for position in positions.flatten()]))

def qlearnVal(ql_states, crr_grid, crr_pos):
    position = findPos(crr_grid)
    if position not in ql_states:
        ql_states[(position, crr_pos)] = 0
    return ql_states[(position, crr_pos)]

def qlearnBestPos(ql_states, crr_grid, availablemoves, epsilon):
    return random.choice(availablemoves) if random.random() < epsilon else max([(qlearnVal(ql_states, crr_grid, position), position) for position in availablemoves], key=lambda x: x[0])[1]

def modifyqLearn(ql_states, crr_grid, crr_pos, reward, nextgrid, availablemoves, alpha=0.1, gamma=0.99):
    qvalb = max([qlearnVal(ql_states, nextgrid, nextpos) for nextpos in availablemoves], default=0)
    qvalopti = qlearnVal(ql_states, crr_grid, crr_pos) + alpha * ((reward + gamma * qvalb) - qlearnVal(ql_states, crr_grid, crr_pos))
    position = findPos(crr_grid)
    ql_states[(position, crr_pos)] = qvalopti

def modifyExploration(epsilon):
    return max(epsilon * 0.999, 0.1)

def dumpModel(ql_states, file_path="connect4_QL_500k.pickle"):
    with open(file_path, "wb") as file:
        pickle.dump(ql_states, file)

def trainQLearn():
    ql_states = {}
    ql_win = def_win = draw = 0
    qlmarkr = 1
    defaultmark = 2
    total_episodes = 500000
    
    for episode in range(total_episodes):
        board = gameBoard()
        epsilon = 1.0

        while True:
            ql_availablemoves = legalMove(board)

            if len(ql_availablemoves) == 0:
                break

            qlCol = qlearnBestPos(ql_states, board, ql_availablemoves, epsilon)
            qlRow = availableRow(board, qlCol)
            board[qlRow][qlCol] = qlmarkr

            if checkWin(board, qlmarkr):
                ql_win += 1
                modifyqLearn(ql_states, board, qlCol, 1, board, [])
                break
            elif checkWin(board, defaultmark):
                def_win += 1
                modifyqLearn(ql_states, board, qlCol, -1, board, [])
                break
            elif len(legalMove(board)) == 0:
                draw += 1
                modifyqLearn(ql_states, board, qlCol, 0, board, [])
                break
            else:
                modifyqLearn(ql_states, board, qlCol, 0, board, legalMove(board))

            defRow, defCol = defaultPlayerMove(board, board, defaultmark, qlmarkr)
            board[defRow][defCol] = defaultmark

            if checkWin(board, qlmarkr):
                ql_win += 1
                modifyqLearn(ql_states, board, defCol, 1, board, [])
                break
            elif checkWin(board, defaultmark):
                def_win += 1
                modifyqLearn(ql_states, board, defCol, -1, board, [])
                break
            elif len(legalMove(board)) == 0:
                draw += 1
                modifyqLearn(ql_states, board, defCol, 0, board, [])
                break
            else:
                modifyqLearn(ql_states, board, defCol, 0, board, legalMove(board))

            epsilon = modifyExploration(epsilon)

        if episode % 1000 == 0:
            print(f"Episode {episode}: QLearning wins - {ql_win}, Default Player wins - {def_win}, Draws - {draw}")

    return ql_states, ql_win, def_win, draw, total_episodes

ql_states, ql_win, def_win, draw, total_episodes = trainQLearn()

print(f"QLearning wins: {ql_win}")
print(f"Default Player wins: {def_win}")
print(f"Draws: {draw}")
print(f"Total Episodes: {total_episodes}")

dumpModel(ql_states)
# Out:
# Episode 0: QLearning wins - 1, SI Agent wins - 0, Draws - 0
# Episode 1000: QLearning wins - 672, SI Agent wins - 317, Draws - 12
# Episode 2000: QLearning wins - 1345, SI Agent wins - 631, Draws - 25
# Episode 3000: QLearning wins - 2017, SI Agent wins - 945, Draws - 39
# Episode 4000: QLearning wins - 2663, SI Agent wins - 1279, Draws - 59
# Episode 5000: QLearning wins - 3326, SI Agent wins - 1598, Draws - 77
# Episode 6000: QLearning wins - 3986, SI Agent wins - 1925, Draws - 90
# Episode 7000: QLearning wins - 4613, SI Agent wins - 2282, Draws - 106
# Episode 8000: QLearning wins - 5270, SI Agent wins - 2610, Draws - 121
# Episode 9000: QLearning wins - 5908, SI Agent wins - 2959, Draws - 134
# Episode 10000: QLearning wins - 6551, SI Agent wins - 3298, Draws - 152
# Episode 11000: QLearning wins - 7183, SI Agent wins - 3650, Draws - 168
# Episode 12000: QLearning wins - 7843, SI Agent wins - 3981, Draws - 177
# Episode 13000: QLearning wins - 8498, SI Agent wins - 4310, Draws - 193
# Episode 14000: QLearning wins - 9164, SI Agent wins - 4636, Draws - 201
# Episode 15000: QLearning wins - 9800, SI Agent wins - 4979, Draws - 222
# Episode 16000: QLearning wins - 10472, SI Agent wins - 5291, Draws - 238
# Episode 17000: QLearning wins - 11132, SI Agent wins - 5619, Draws - 250
# Episode 18000: QLearning wins - 11794, SI Agent wins - 5941, Draws - 266
# Episode 19000: QLearning wins - 12466, SI Agent wins - 6258, Draws - 277
# Episode 20000: QLearning wins - 13127, SI Agent wins - 6580, Draws - 294
# Episode 21000: QLearning wins - 13778, SI Agent wins - 6915, Draws - 308
# Episode 22000: QLearning wins - 14419, SI Agent wins - 7263, Draws - 319
# Episode 23000: QLearning wins - 15070, SI Agent wins - 7593, Draws - 338
# Episode 24000: QLearning wins - 15729, SI Agent wins - 7919, Draws - 353
# Episode 25000: QLearning wins - 16387, SI Agent wins - 8247, Draws - 367
# Episode 26000: QLearning wins - 17024, SI Agent wins - 8594, Draws - 383
# Episode 27000: QLearning wins - 17674, SI Agent wins - 8927, Draws - 400
# Episode 28000: QLearning wins - 18318, SI Agent wins - 9268, Draws - 415
# Episode 29000: QLearning wins - 18974, SI Agent wins - 9594, Draws - 433
# Episode 30000: QLearning wins - 19612, SI Agent wins - 9937, Draws - 452
# Episode 31000: QLearning wins - 20275, SI Agent wins - 10257, Draws - 469
# Episode 32000: QLearning wins - 20934, SI Agent wins - 10586, Draws - 481
# Episode 33000: QLearning wins - 21593, SI Agent wins - 10912, Draws - 496
# Episode 34000: QLearning wins - 22244, SI Agent wins - 11241, Draws - 516
# Episode 35000: QLearning wins - 22889, SI Agent wins - 11581, Draws - 531
# Episode 36000: QLearning wins - 23549, SI Agent wins - 11913, Draws - 539
# Episode 37000: QLearning wins - 24209, SI Agent wins - 12238, Draws - 554
# Episode 38000: QLearning wins - 24869, SI Agent wins - 12565, Draws - 567
# Episode 39000: QLearning wins - 25524, SI Agent wins - 12901, Draws - 576
# Episode 40000: QLearning wins - 26201, SI Agent wins - 13215, Draws - 585
# Episode 41000: QLearning wins - 26856, SI Agent wins - 13543, Draws - 602
# Episode 42000: QLearning wins - 27508, SI Agent wins - 13869, Draws - 624
# Episode 43000: QLearning wins - 28208, SI Agent wins - 14161, Draws - 632
# Episode 44000: QLearning wins - 28865, SI Agent wins - 14488, Draws - 648
# Episode 45000: QLearning wins - 29503, SI Agent wins - 14834, Draws - 664
# Episode 46000: QLearning wins - 30163, SI Agent wins - 15158, Draws - 680
# Episode 47000: QLearning wins - 30808, SI Agent wins - 15494, Draws - 699
# Episode 48000: QLearning wins - 31466, SI Agent wins - 15817, Draws - 718
# Episode 49000: QLearning wins - 32124, SI Agent wins - 16147, Draws - 730
# Episode 50000: QLearning wins - 32766, SI Agent wins - 16489, Draws - 746
# Episode 51000: QLearning wins - 33460, SI Agent wins - 16784, Draws - 757
# Episode 52000: QLearning wins - 34118, SI Agent wins - 17111, Draws - 772
# Episode 53000: QLearning wins - 34801, SI Agent wins - 17412, Draws - 788
# Episode 54000: QLearning wins - 35448, SI Agent wins - 17740, Draws - 813
# Episode 55000: QLearning wins - 36113, SI Agent wins - 18062, Draws - 826
# Episode 56000: QLearning wins - 36765, SI Agent wins - 18394, Draws - 842
# Episode 57000: QLearning wins - 37430, SI Agent wins - 18717, Draws - 854
# Episode 58000: QLearning wins - 38092, SI Agent wins - 19045, Draws - 864
# Episode 59000: QLearning wins - 38741, SI Agent wins - 19382, Draws - 878
# Episode 60000: QLearning wins - 39409, SI Agent wins - 19704, Draws - 888
# Episode 61000: QLearning wins - 40078, SI Agent wins - 20022, Draws - 901
# Episode 62000: QLearning wins - 40748, SI Agent wins - 20336, Draws - 917
# Episode 63000: QLearning wins - 41429, SI Agent wins - 20639, Draws - 933
# Episode 64000: QLearning wins - 42066, SI Agent wins - 20991, Draws - 944
# Episode 65000: QLearning wins - 42695, SI Agent wins - 21347, Draws - 959
# Episode 66000: QLearning wins - 43357, SI Agent wins - 21666, Draws - 978
# Episode 67000: QLearning wins - 44014, SI Agent wins - 22001, Draws - 986
# Episode 68000: QLearning wins - 44659, SI Agent wins - 22341, Draws - 1001
# Episode 69000: QLearning wins - 45344, SI Agent wins - 22645, Draws - 1012
# Episode 70000: QLearning wins - 45988, SI Agent wins - 22988, Draws - 1025
# Episode 71000: QLearning wins - 46640, SI Agent wins - 23323, Draws - 1038
# Episode 72000: QLearning wins - 47299, SI Agent wins - 23651, Draws - 1051
# Episode 73000: QLearning wins - 47948, SI Agent wins - 23990, Draws - 1063
# Episode 74000: QLearning wins - 48621, SI Agent wins - 24304, Draws - 1076
# Episode 75000: QLearning wins - 49282, SI Agent wins - 24634, Draws - 1085
# Episode 76000: QLearning wins - 49989, SI Agent wins - 24909, Draws - 1103
# Episode 77000: QLearning wins - 50641, SI Agent wins - 25242, Draws - 1118
# Episode 78000: QLearning wins - 51292, SI Agent wins - 25579, Draws - 1130
# Episode 79000: QLearning wins - 51965, SI Agent wins - 25892, Draws - 1144
# Episode 80000: QLearning wins - 52624, SI Agent wins - 26208, Draws - 1169
# Episode 81000: QLearning wins - 53275, SI Agent wins - 26546, Draws - 1180
# Episode 82000: QLearning wins - 53927, SI Agent wins - 26881, Draws - 1193
# Episode 83000: QLearning wins - 54583, SI Agent wins - 27207, Draws - 1211
# Episode 84000: QLearning wins - 55250, SI Agent wins - 27525, Draws - 1226
# Episode 85000: QLearning wins - 55887, SI Agent wins - 27876, Draws - 1238
# Episode 86000: QLearning wins - 56541, SI Agent wins - 28202, Draws - 1258
# Episode 87000: QLearning wins - 57210, SI Agent wins - 28513, Draws - 1278
# Episode 88000: QLearning wins - 57874, SI Agent wins - 28835, Draws - 1292
# Episode 89000: QLearning wins - 58513, SI Agent wins - 29180, Draws - 1308
# Episode 90000: QLearning wins - 59175, SI Agent wins - 29513, Draws - 1313
# Episode 91000: QLearning wins - 59845, SI Agent wins - 29835, Draws - 1321
# Episode 92000: QLearning wins - 60506, SI Agent wins - 30158, Draws - 1337
# Episode 93000: QLearning wins - 61145, SI Agent wins - 30507, Draws - 1349
# Episode 94000: QLearning wins - 61807, SI Agent wins - 30830, Draws - 1364
# Episode 95000: QLearning wins - 62474, SI Agent wins - 31149, Draws - 1378
# Episode 96000: QLearning wins - 63138, SI Agent wins - 31470, Draws - 1393
# Episode 97000: QLearning wins - 63794, SI Agent wins - 31799, Draws - 1408
# Episode 98000: QLearning wins - 64447, SI Agent wins - 32129, Draws - 1425
# Episode 99000: QLearning wins - 65106, SI Agent wins - 32458, Draws - 1437
# Episode 100000: QLearning wins - 65736, SI Agent wins - 32810, Draws - 1455
# Episode 101000: QLearning wins - 66382, SI Agent wins - 33152, Draws - 1467
# Episode 102000: QLearning wins - 67031, SI Agent wins - 33486, Draws - 1484
# Episode 103000: QLearning wins - 67704, SI Agent wins - 33795, Draws - 1502
# Episode 104000: QLearning wins - 68361, SI Agent wins - 34119, Draws - 1521
# Episode 105000: QLearning wins - 69011, SI Agent wins - 34456, Draws - 1534
# Episode 106000: QLearning wins - 69661, SI Agent wins - 34786, Draws - 1554
# Episode 107000: QLearning wins - 70316, SI Agent wins - 35123, Draws - 1562
# Episode 108000: QLearning wins - 70965, SI Agent wins - 35453, Draws - 1583
# Episode 109000: QLearning wins - 71621, SI Agent wins - 35780, Draws - 1600
# Episode 110000: QLearning wins - 72280, SI Agent wins - 36111, Draws - 1610
# Episode 111000: QLearning wins - 72921, SI Agent wins - 36452, Draws - 1628
# Episode 112000: QLearning wins - 73573, SI Agent wins - 36785, Draws - 1643
# Episode 113000: QLearning wins - 74236, SI Agent wins - 37107, Draws - 1658
# Episode 114000: QLearning wins - 74869, SI Agent wins - 37461, Draws - 1671
# Episode 115000: QLearning wins - 75526, SI Agent wins - 37787, Draws - 1688
# Episode 116000: QLearning wins - 76201, SI Agent wins - 38095, Draws - 1705
# Episode 117000: QLearning wins - 76849, SI Agent wins - 38429, Draws - 1723
# Episode 118000: QLearning wins - 77516, SI Agent wins - 38747, Draws - 1738
# Episode 119000: QLearning wins - 78164, SI Agent wins - 39089, Draws - 1748
# Episode 120000: QLearning wins - 78838, SI Agent wins - 39395, Draws - 1768
# Episode 121000: QLearning wins - 79460, SI Agent wins - 39755, Draws - 1786
# Episode 122000: QLearning wins - 80101, SI Agent wins - 40096, Draws - 1804
# Episode 123000: QLearning wins - 80764, SI Agent wins - 40419, Draws - 1818
# Episode 124000: QLearning wins - 81438, SI Agent wins - 40729, Draws - 1834
# Episode 125000: QLearning wins - 82104, SI Agent wins - 41052, Draws - 1845
# Episode 126000: QLearning wins - 82766, SI Agent wins - 41382, Draws - 1853
# Episode 127000: QLearning wins - 83408, SI Agent wins - 41729, Draws - 1864
# Episode 128000: QLearning wins - 84066, SI Agent wins - 42046, Draws - 1889
# Episode 129000: QLearning wins - 84740, SI Agent wins - 42358, Draws - 1903
# Episode 130000: QLearning wins - 85386, SI Agent wins - 42691, Draws - 1924
# Episode 131000: QLearning wins - 86031, SI Agent wins - 43038, Draws - 1932
# Episode 132000: QLearning wins - 86707, SI Agent wins - 43349, Draws - 1945
# Episode 133000: QLearning wins - 87385, SI Agent wins - 43660, Draws - 1956
# Episode 134000: QLearning wins - 88017, SI Agent wins - 44007, Draws - 1977
# Episode 135000: QLearning wins - 88679, SI Agent wins - 44327, Draws - 1995
# Episode 136000: QLearning wins - 89322, SI Agent wins - 44673, Draws - 2006
# Episode 137000: QLearning wins - 89977, SI Agent wins - 45005, Draws - 2019
# Episode 138000: QLearning wins - 90651, SI Agent wins - 45315, Draws - 2035
# Episode 139000: QLearning wins - 91295, SI Agent wins - 45651, Draws - 2055
# Episode 140000: QLearning wins - 91956, SI Agent wins - 45973, Draws - 2072
# Episode 141000: QLearning wins - 92608, SI Agent wins - 46306, Draws - 2087
# Episode 142000: QLearning wins - 93254, SI Agent wins - 46646, Draws - 2101
# Episode 143000: QLearning wins - 93923, SI Agent wins - 46969, Draws - 2109
# Episode 144000: QLearning wins - 94588, SI Agent wins - 47293, Draws - 2120
# Episode 145000: QLearning wins - 95248, SI Agent wins - 47610, Draws - 2143
# Episode 146000: QLearning wins - 95888, SI Agent wins - 47959, Draws - 2154
# Episode 147000: QLearning wins - 96554, SI Agent wins - 48275, Draws - 2172
# Episode 148000: QLearning wins - 97205, SI Agent wins - 48609, Draws - 2187
# Episode 149000: QLearning wins - 97868, SI Agent wins - 48931, Draws - 2202
# Episode 150000: QLearning wins - 98527, SI Agent wins - 49264, Draws - 2210
# Episode 151000: QLearning wins - 99189, SI Agent wins - 49588, Draws - 2224
# Episode 152000: QLearning wins - 99829, SI Agent wins - 49930, Draws - 2242
# Episode 153000: QLearning wins - 100460, SI Agent wins - 50284, Draws - 2257
# Episode 154000: QLearning wins - 101123, SI Agent wins - 50610, Draws - 2268
# Episode 155000: QLearning wins - 101771, SI Agent wins - 50943, Draws - 2287
# Episode 156000: QLearning wins - 102422, SI Agent wins - 51276, Draws - 2303
# Episode 157000: QLearning wins - 103092, SI Agent wins - 51590, Draws - 2319
# Episode 158000: QLearning wins - 103752, SI Agent wins - 51914, Draws - 2335
# Episode 159000: QLearning wins - 104438, SI Agent wins - 52217, Draws - 2346
# Episode 160000: QLearning wins - 105092, SI Agent wins - 52549, Draws - 2360
# Episode 161000: QLearning wins - 105741, SI Agent wins - 52894, Draws - 2366
# Episode 162000: QLearning wins - 106411, SI Agent wins - 53206, Draws - 2384
# Episode 163000: QLearning wins - 107087, SI Agent wins - 53515, Draws - 2399
# Episode 164000: QLearning wins - 107768, SI Agent wins - 53818, Draws - 2415
# Episode 165000: QLearning wins - 108440, SI Agent wins - 54134, Draws - 2427
# Episode 166000: QLearning wins - 109085, SI Agent wins - 54476, Draws - 2440
# Episode 167000: QLearning wins - 109767, SI Agent wins - 54779, Draws - 2455
# Episode 168000: QLearning wins - 110433, SI Agent wins - 55095, Draws - 2473
# Episode 169000: QLearning wins - 111081, SI Agent wins - 55435, Draws - 2485
# Episode 170000: QLearning wins - 111724, SI Agent wins - 55773, Draws - 2504
# Episode 171000: QLearning wins - 112344, SI Agent wins - 56132, Draws - 2525
# Episode 172000: QLearning wins - 112977, SI Agent wins - 56482, Draws - 2542
# Episode 173000: QLearning wins - 113619, SI Agent wins - 56824, Draws - 2558
# Episode 174000: QLearning wins - 114259, SI Agent wins - 57170, Draws - 2572
# Episode 175000: QLearning wins - 114905, SI Agent wins - 57515, Draws - 2581
# Episode 176000: QLearning wins - 115538, SI Agent wins - 57864, Draws - 2599
# Episode 177000: QLearning wins - 116178, SI Agent wins - 58211, Draws - 2612
# Episode 178000: QLearning wins - 116849, SI Agent wins - 58525, Draws - 2627
# Episode 179000: QLearning wins - 117521, SI Agent wins - 58846, Draws - 2634
# Episode 180000: QLearning wins - 118180, SI Agent wins - 59175, Draws - 2646
# Episode 181000: QLearning wins - 118822, SI Agent wins - 59521, Draws - 2658
# Episode 182000: QLearning wins - 119467, SI Agent wins - 59863, Draws - 2671
# Episode 183000: QLearning wins - 120146, SI Agent wins - 60172, Draws - 2683
# Episode 184000: QLearning wins - 120809, SI Agent wins - 60495, Draws - 2697
# Episode 185000: QLearning wins - 121435, SI Agent wins - 60847, Draws - 2719
# Episode 186000: QLearning wins - 122100, SI Agent wins - 61164, Draws - 2737
# Episode 187000: QLearning wins - 122739, SI Agent wins - 61505, Draws - 2757
# Episode 188000: QLearning wins - 123396, SI Agent wins - 61836, Draws - 2769
# Episode 189000: QLearning wins - 124044, SI Agent wins - 62169, Draws - 2788
# Episode 190000: QLearning wins - 124676, SI Agent wins - 62515, Draws - 2810
# Episode 191000: QLearning wins - 125325, SI Agent wins - 62847, Draws - 2829
# Episode 192000: QLearning wins - 125989, SI Agent wins - 63172, Draws - 2840
# Episode 193000: QLearning wins - 126632, SI Agent wins - 63510, Draws - 2859
# Episode 194000: QLearning wins - 127289, SI Agent wins - 63843, Draws - 2869
# Episode 195000: QLearning wins - 127958, SI Agent wins - 64161, Draws - 2882
# Episode 196000: QLearning wins - 128595, SI Agent wins - 64502, Draws - 2904
# Episode 197000: QLearning wins - 129246, SI Agent wins - 64835, Draws - 2920
# Episode 198000: QLearning wins - 129902, SI Agent wins - 65161, Draws - 2938
# Episode 199000: QLearning wins - 130545, SI Agent wins - 65495, Draws - 2961
# Episode 200000: QLearning wins - 131203, SI Agent wins - 65824, Draws - 2974
# Episode 201000: QLearning wins - 131853, SI Agent wins - 66162, Draws - 2986
# Episode 202000: QLearning wins - 132535, SI Agent wins - 66473, Draws - 2993
# Episode 203000: QLearning wins - 133164, SI Agent wins - 66834, Draws - 3003
# Episode 204000: QLearning wins - 133824, SI Agent wins - 67165, Draws - 3012
# Episode 205000: QLearning wins - 134466, SI Agent wins - 67507, Draws - 3028
# Episode 206000: QLearning wins - 135117, SI Agent wins - 67843, Draws - 3041
# Episode 207000: QLearning wins - 135786, SI Agent wins - 68162, Draws - 3053
# Episode 208000: QLearning wins - 136455, SI Agent wins - 68473, Draws - 3073
# Episode 209000: QLearning wins - 137093, SI Agent wins - 68820, Draws - 3088
# Episode 210000: QLearning wins - 137746, SI Agent wins - 69145, Draws - 3110
# Episode 211000: QLearning wins - 138407, SI Agent wins - 69468, Draws - 3126
# Episode 212000: QLearning wins - 139075, SI Agent wins - 69788, Draws - 3138
# Episode 213000: QLearning wins - 139727, SI Agent wins - 70118, Draws - 3156
# Episode 214000: QLearning wins - 140384, SI Agent wins - 70447, Draws - 3170
# Episode 215000: QLearning wins - 141066, SI Agent wins - 70752, Draws - 3183
# Episode 216000: QLearning wins - 141717, SI Agent wins - 71089, Draws - 3195
# Episode 217000: QLearning wins - 142397, SI Agent wins - 71391, Draws - 3213
# Episode 218000: QLearning wins - 143035, SI Agent wins - 71740, Draws - 3226
# Episode 219000: QLearning wins - 143684, SI Agent wins - 72075, Draws - 3242
# Episode 220000: QLearning wins - 144350, SI Agent wins - 72396, Draws - 3255
# Episode 221000: QLearning wins - 144999, SI Agent wins - 72736, Draws - 3266
# Episode 222000: QLearning wins - 145643, SI Agent wins - 73073, Draws - 3285
# Episode 223000: QLearning wins - 146296, SI Agent wins - 73407, Draws - 3298
# Episode 224000: QLearning wins - 146964, SI Agent wins - 73723, Draws - 3314
# Episode 225000: QLearning wins - 147603, SI Agent wins - 74073, Draws - 3325
# Episode 226000: QLearning wins - 148292, SI Agent wins - 74375, Draws - 3334
# Episode 227000: QLearning wins - 148955, SI Agent wins - 74693, Draws - 3353
# Episode 228000: QLearning wins - 149602, SI Agent wins - 75026, Draws - 3373
# Episode 229000: QLearning wins - 150256, SI Agent wins - 75360, Draws - 3385
# Episode 230000: QLearning wins - 150893, SI Agent wins - 75700, Draws - 3408
# Episode 231000: QLearning wins - 151548, SI Agent wins - 76030, Draws - 3423
# Episode 232000: QLearning wins - 152212, SI Agent wins - 76351, Draws - 3438
# Episode 233000: QLearning wins - 152887, SI Agent wins - 76664, Draws - 3450
# Episode 234000: QLearning wins - 153521, SI Agent wins - 77020, Draws - 3460
# Episode 235000: QLearning wins - 154172, SI Agent wins - 77358, Draws - 3471
# Episode 236000: QLearning wins - 154819, SI Agent wins - 77697, Draws - 3485
# Episode 237000: QLearning wins - 155484, SI Agent wins - 78018, Draws - 3499
# Episode 238000: QLearning wins - 156124, SI Agent wins - 78367, Draws - 3510
# Episode 239000: QLearning wins - 156784, SI Agent wins - 78698, Draws - 3519
# Episode 240000: QLearning wins - 157452, SI Agent wins - 79020, Draws - 3529
# Episode 241000: QLearning wins - 158107, SI Agent wins - 79341, Draws - 3553
# Episode 242000: QLearning wins - 158747, SI Agent wins - 79683, Draws - 3571
# Episode 243000: QLearning wins - 159417, SI Agent wins - 79996, Draws - 3588
# Episode 244000: QLearning wins - 160098, SI Agent wins - 80308, Draws - 3595
# Episode 245000: QLearning wins - 160779, SI Agent wins - 80606, Draws - 3616
# Episode 246000: QLearning wins - 161437, SI Agent wins - 80936, Draws - 3628
# Episode 247000: QLearning wins - 162089, SI Agent wins - 81273, Draws - 3639
# Episode 248000: QLearning wins - 162754, SI Agent wins - 81598, Draws - 3649
# Episode 249000: QLearning wins - 163429, SI Agent wins - 81906, Draws - 3666
# Episode 250000: QLearning wins - 164086, SI Agent wins - 82237, Draws - 3678
# Episode 251000: QLearning wins - 164743, SI Agent wins - 82567, Draws - 3691
# Episode 252000: QLearning wins - 165409, SI Agent wins - 82893, Draws - 3699
# Episode 253000: QLearning wins - 166069, SI Agent wins - 83215, Draws - 3717
# Episode 254000: QLearning wins - 166732, SI Agent wins - 83539, Draws - 3730
# Episode 255000: QLearning wins - 167388, SI Agent wins - 83872, Draws - 3741
# Episode 256000: QLearning wins - 168049, SI Agent wins - 84196, Draws - 3756
# Episode 257000: QLearning wins - 168715, SI Agent wins - 84521, Draws - 3765
# Episode 258000: QLearning wins - 169393, SI Agent wins - 84832, Draws - 3776
# Episode 259000: QLearning wins - 170068, SI Agent wins - 85144, Draws - 3789
# Episode 260000: QLearning wins - 170739, SI Agent wins - 85456, Draws - 3806
# Episode 261000: QLearning wins - 171410, SI Agent wins - 85773, Draws - 3818
# Episode 262000: QLearning wins - 172075, SI Agent wins - 86092, Draws - 3834
# Episode 263000: QLearning wins - 172715, SI Agent wins - 86433, Draws - 3853
# Episode 264000: QLearning wins - 173412, SI Agent wins - 86723, Draws - 3866
# Episode 265000: QLearning wins - 174070, SI Agent wins - 87051, Draws - 3880
# Episode 266000: QLearning wins - 174753, SI Agent wins - 87354, Draws - 3894
# Episode 267000: QLearning wins - 175418, SI Agent wins - 87679, Draws - 3904
# Episode 268000: QLearning wins - 176081, SI Agent wins - 88001, Draws - 3919
# Episode 269000: QLearning wins - 176755, SI Agent wins - 88305, Draws - 3941
# Episode 270000: QLearning wins - 177423, SI Agent wins - 88625, Draws - 3953
# Episode 271000: QLearning wins - 178096, SI Agent wins - 88934, Draws - 3971
# Episode 272000: QLearning wins - 178749, SI Agent wins - 89258, Draws - 3994
# Episode 273000: QLearning wins - 179405, SI Agent wins - 89586, Draws - 4010
# Episode 274000: QLearning wins - 180072, SI Agent wins - 89908, Draws - 4021
# Episode 275000: QLearning wins - 180729, SI Agent wins - 90237, Draws - 4035
# Episode 276000: QLearning wins - 181356, SI Agent wins - 90589, Draws - 4056
# Episode 277000: QLearning wins - 182012, SI Agent wins - 90923, Draws - 4066
# Episode 278000: QLearning wins - 182653, SI Agent wins - 91271, Draws - 4077
# Episode 279000: QLearning wins - 183315, SI Agent wins - 91596, Draws - 4090
# Episode 280000: QLearning wins - 183972, SI Agent wins - 91923, Draws - 4106
# Episode 281000: QLearning wins - 184655, SI Agent wins - 92226, Draws - 4120
# Episode 282000: QLearning wins - 185353, SI Agent wins - 92511, Draws - 4137
# Episode 283000: QLearning wins - 186005, SI Agent wins - 92845, Draws - 4151
# Episode 284000: QLearning wins - 186649, SI Agent wins - 93181, Draws - 4171
# Episode 285000: QLearning wins - 187289, SI Agent wins - 93531, Draws - 4181
# Episode 286000: QLearning wins - 187965, SI Agent wins - 93841, Draws - 4195
# Episode 287000: QLearning wins - 188633, SI Agent wins - 94160, Draws - 4208
# Episode 288000: QLearning wins - 189273, SI Agent wins - 94514, Draws - 4214
# Episode 289000: QLearning wins - 189921, SI Agent wins - 94853, Draws - 4227
# Episode 290000: QLearning wins - 190566, SI Agent wins - 95190, Draws - 4245
# Episode 291000: QLearning wins - 191211, SI Agent wins - 95535, Draws - 4255
# Episode 292000: QLearning wins - 191879, SI Agent wins - 95854, Draws - 4268
# Episode 293000: QLearning wins - 192546, SI Agent wins - 96176, Draws - 4279
# Episode 294000: QLearning wins - 193213, SI Agent wins - 96493, Draws - 4295
# Episode 295000: QLearning wins - 193896, SI Agent wins - 96795, Draws - 4310
# Episode 296000: QLearning wins - 194569, SI Agent wins - 97109, Draws - 4323
# Episode 297000: QLearning wins - 195200, SI Agent wins - 97467, Draws - 4334
# Episode 298000: QLearning wins - 195856, SI Agent wins - 97790, Draws - 4355
# Episode 299000: QLearning wins - 196510, SI Agent wins - 98117, Draws - 4374
# Episode 300000: QLearning wins - 197186, SI Agent wins - 98427, Draws - 4388
# Episode 301000: QLearning wins - 197861, SI Agent wins - 98740, Draws - 4400
# Episode 302000: QLearning wins - 198507, SI Agent wins - 99084, Draws - 4410
# Episode 303000: QLearning wins - 199168, SI Agent wins - 99413, Draws - 4420
# Episode 304000: QLearning wins - 199817, SI Agent wins - 99744, Draws - 4440
# Episode 305000: QLearning wins - 200465, SI Agent wins - 100081, Draws - 4455
# Episode 306000: QLearning wins - 201135, SI Agent wins - 100397, Draws - 4469
# Episode 307000: QLearning wins - 201784, SI Agent wins - 100726, Draws - 4491
# Episode 308000: QLearning wins - 202430, SI Agent wins - 101058, Draws - 4513
# Episode 309000: QLearning wins - 203054, SI Agent wins - 101420, Draws - 4527
# Episode 310000: QLearning wins - 203728, SI Agent wins - 101731, Draws - 4542
# Episode 311000: QLearning wins - 204383, SI Agent wins - 102059, Draws - 4559
# Episode 312000: QLearning wins - 205079, SI Agent wins - 102349, Draws - 4573
# Episode 313000: QLearning wins - 205734, SI Agent wins - 102689, Draws - 4578
# Episode 314000: QLearning wins - 206391, SI Agent wins - 103023, Draws - 4587
# Episode 315000: QLearning wins - 207049, SI Agent wins - 103350, Draws - 4602
# Episode 316000: QLearning wins - 207716, SI Agent wins - 103668, Draws - 4617
# Episode 317000: QLearning wins - 208391, SI Agent wins - 103978, Draws - 4632
# Episode 318000: QLearning wins - 209055, SI Agent wins - 104296, Draws - 4650
# Episode 319000: QLearning wins - 209713, SI Agent wins - 104626, Draws - 4662
# Episode 320000: QLearning wins - 210369, SI Agent wins - 104950, Draws - 4682
# Episode 321000: QLearning wins - 211009, SI Agent wins - 105297, Draws - 4695
# Episode 322000: QLearning wins - 211681, SI Agent wins - 105608, Draws - 4712
# Episode 323000: QLearning wins - 212319, SI Agent wins - 105958, Draws - 4724
# Episode 324000: QLearning wins - 212990, SI Agent wins - 106271, Draws - 4740
# Episode 325000: QLearning wins - 213648, SI Agent wins - 106599, Draws - 4754
# Episode 326000: QLearning wins - 214313, SI Agent wins - 106924, Draws - 4764
# Episode 327000: QLearning wins - 214991, SI Agent wins - 107234, Draws - 4776
# Episode 328000: QLearning wins - 215681, SI Agent wins - 107529, Draws - 4791
# Episode 329000: QLearning wins - 216343, SI Agent wins - 107850, Draws - 4808
# Episode 330000: QLearning wins - 216999, SI Agent wins - 108187, Draws - 4815
# Episode 331000: QLearning wins - 217650, SI Agent wins - 108519, Draws - 4832
# Episode 332000: QLearning wins - 218300, SI Agent wins - 108853, Draws - 4848
# Episode 333000: QLearning wins - 218961, SI Agent wins - 109172, Draws - 4868
# Episode 334000: QLearning wins - 219644, SI Agent wins - 109482, Draws - 4875
# Episode 335000: QLearning wins - 220317, SI Agent wins - 109792, Draws - 4892
# Episode 336000: QLearning wins - 220993, SI Agent wins - 110108, Draws - 4900
# Episode 337000: QLearning wins - 221646, SI Agent wins - 110440, Draws - 4915
# Episode 338000: QLearning wins - 222318, SI Agent wins - 110749, Draws - 4934
# Episode 339000: QLearning wins - 222954, SI Agent wins - 111102, Draws - 4945
# Episode 340000: QLearning wins - 223594, SI Agent wins - 111445, Draws - 4962
# Episode 341000: QLearning wins - 224249, SI Agent wins - 111775, Draws - 4977
# Episode 342000: QLearning wins - 224911, SI Agent wins - 112101, Draws - 4989
# Episode 343000: QLearning wins - 225589, SI Agent wins - 112411, Draws - 5001
# Episode 344000: QLearning wins - 226214, SI Agent wins - 112769, Draws - 5018
# Episode 345000: QLearning wins - 226873, SI Agent wins - 113099, Draws - 5029
# Episode 346000: QLearning wins - 227534, SI Agent wins - 113421, Draws - 5046
# Episode 347000: QLearning wins - 228203, SI Agent wins - 113737, Draws - 5061
# Episode 348000: QLearning wins - 228879, SI Agent wins - 114050, Draws - 5072
# Episode 349000: QLearning wins - 229534, SI Agent wins - 114379, Draws - 5088
# Episode 350000: QLearning wins - 230179, SI Agent wins - 114722, Draws - 5100
# Episode 351000: QLearning wins - 230854, SI Agent wins - 115030, Draws - 5117
# Episode 352000: QLearning wins - 231504, SI Agent wins - 115372, Draws - 5125
# Episode 353000: QLearning wins - 232172, SI Agent wins - 115688, Draws - 5141
# Episode 354000: QLearning wins - 232867, SI Agent wins - 115982, Draws - 5152
# Episode 355000: QLearning wins - 233519, SI Agent wins - 116321, Draws - 5161
# Episode 356000: QLearning wins - 234188, SI Agent wins - 116632, Draws - 5181
# Episode 357000: QLearning wins - 234836, SI Agent wins - 116967, Draws - 5198
# Episode 358000: QLearning wins - 235493, SI Agent wins - 117298, Draws - 5210
# Episode 359000: QLearning wins - 236159, SI Agent wins - 117617, Draws - 5225
# Episode 360000: QLearning wins - 236788, SI Agent wins - 117971, Draws - 5242
# Episode 361000: QLearning wins - 237439, SI Agent wins - 118310, Draws - 5252
# Episode 362000: QLearning wins - 238089, SI Agent wins - 118646, Draws - 5266
# Episode 363000: QLearning wins - 238764, SI Agent wins - 118958, Draws - 5279
# Episode 364000: QLearning wins - 239405, SI Agent wins - 119301, Draws - 5295
# Episode 365000: QLearning wins - 240036, SI Agent wins - 119651, Draws - 5314
# Episode 366000: QLearning wins - 240712, SI Agent wins - 119963, Draws - 5326
# Episode 367000: QLearning wins - 241383, SI Agent wins - 120282, Draws - 5336
# Episode 368000: QLearning wins - 242056, SI Agent wins - 120592, Draws - 5353
# Episode 369000: QLearning wins - 242735, SI Agent wins - 120897, Draws - 5369
# Episode 370000: QLearning wins - 243423, SI Agent wins - 121192, Draws - 5386
# Episode 371000: QLearning wins - 244065, SI Agent wins - 121539, Draws - 5397
# Episode 372000: QLearning wins - 244739, SI Agent wins - 121856, Draws - 5406
# Episode 373000: QLearning wins - 245396, SI Agent wins - 122180, Draws - 5425
# Episode 374000: QLearning wins - 246090, SI Agent wins - 122465, Draws - 5446
# Episode 375000: QLearning wins - 246753, SI Agent wins - 122785, Draws - 5463
# Episode 376000: QLearning wins - 247427, SI Agent wins - 123094, Draws - 5480
# Episode 377000: QLearning wins - 248094, SI Agent wins - 123409, Draws - 5498
# Episode 378000: QLearning wins - 248742, SI Agent wins - 123743, Draws - 5516
# Episode 379000: QLearning wins - 249400, SI Agent wins - 124069, Draws - 5532
# Episode 380000: QLearning wins - 250050, SI Agent wins - 124401, Draws - 5550
# Episode 381000: QLearning wins - 250688, SI Agent wins - 124752, Draws - 5561
# Episode 382000: QLearning wins - 251351, SI Agent wins - 125073, Draws - 5577
# Episode 383000: QLearning wins - 252033, SI Agent wins - 125378, Draws - 5590
# Episode 384000: QLearning wins - 252683, SI Agent wins - 125712, Draws - 5606
# Episode 385000: QLearning wins - 253328, SI Agent wins - 126049, Draws - 5624
# Episode 386000: QLearning wins - 253981, SI Agent wins - 126381, Draws - 5639
# Episode 387000: QLearning wins - 254637, SI Agent wins - 126709, Draws - 5655
# Episode 388000: QLearning wins - 255286, SI Agent wins - 127037, Draws - 5678
# Episode 389000: QLearning wins - 255932, SI Agent wins - 127380, Draws - 5689
# Episode 390000: QLearning wins - 256582, SI Agent wins - 127722, Draws - 5697
# Episode 391000: QLearning wins - 257248, SI Agent wins - 128039, Draws - 5714
# Episode 392000: QLearning wins - 257927, SI Agent wins - 128345, Draws - 5729
# Episode 393000: QLearning wins - 258575, SI Agent wins - 128685, Draws - 5741
# Episode 394000: QLearning wins - 259225, SI Agent wins - 129021, Draws - 5755
# Episode 395000: QLearning wins - 259874, SI Agent wins - 129351, Draws - 5776
# Episode 396000: QLearning wins - 260546, SI Agent wins - 129651, Draws - 5804
# Episode 397000: QLearning wins - 261201, SI Agent wins - 129976, Draws - 5824
# Episode 398000: QLearning wins - 261862, SI Agent wins - 130306, Draws - 5833
# Episode 399000: QLearning wins - 262550, SI Agent wins - 130599, Draws - 5852
# Episode 400000: QLearning wins - 263224, SI Agent wins - 130903, Draws - 5874
# Episode 401000: QLearning wins - 263883, SI Agent wins - 131228, Draws - 5890
# Episode 402000: QLearning wins - 264562, SI Agent wins - 131536, Draws - 5903
# Episode 403000: QLearning wins - 265211, SI Agent wins - 131873, Draws - 5917
# Episode 404000: QLearning wins - 265878, SI Agent wins - 132188, Draws - 5935
# Episode 405000: QLearning wins - 266529, SI Agent wins - 132521, Draws - 5951
# Episode 406000: QLearning wins - 267170, SI Agent wins - 132865, Draws - 5966
# Episode 407000: QLearning wins - 267834, SI Agent wins - 133189, Draws - 5978
# Episode 408000: QLearning wins - 268485, SI Agent wins - 133523, Draws - 5993
# Episode 409000: QLearning wins - 269138, SI Agent wins - 133859, Draws - 6004
# Episode 410000: QLearning wins - 269778, SI Agent wins - 134202, Draws - 6021
# Episode 411000: QLearning wins - 270452, SI Agent wins - 134511, Draws - 6038
# Episode 412000: QLearning wins - 271117, SI Agent wins - 134832, Draws - 6052
# Episode 413000: QLearning wins - 271786, SI Agent wins - 135142, Draws - 6073
# Episode 414000: QLearning wins - 272473, SI Agent wins - 135446, Draws - 6082
# Episode 415000: QLearning wins - 273132, SI Agent wins - 135771, Draws - 6098
# Episode 416000: QLearning wins - 273806, SI Agent wins - 136080, Draws - 6115
# Episode 417000: QLearning wins - 274450, SI Agent wins - 136420, Draws - 6131
# Episode 418000: QLearning wins - 275097, SI Agent wins - 136757, Draws - 6147
# Episode 419000: QLearning wins - 275777, SI Agent wins - 137059, Draws - 6165
# Episode 420000: QLearning wins - 276436, SI Agent wins - 137376, Draws - 6189
# Episode 421000: QLearning wins - 277108, SI Agent wins - 137691, Draws - 6202
# Episode 422000: QLearning wins - 277757, SI Agent wins - 138026, Draws - 6218
# Episode 423000: QLearning wins - 278419, SI Agent wins - 138350, Draws - 6232
# Episode 424000: QLearning wins - 279083, SI Agent wins - 138681, Draws - 6237
# Episode 425000: QLearning wins - 279730, SI Agent wins - 139027, Draws - 6244
# Episode 426000: QLearning wins - 280392, SI Agent wins - 139350, Draws - 6259
# Episode 427000: QLearning wins - 281032, SI Agent wins - 139694, Draws - 6275
# Episode 428000: QLearning wins - 281695, SI Agent wins - 140014, Draws - 6292
# Episode 429000: QLearning wins - 282352, SI Agent wins - 140337, Draws - 6312
# Episode 430000: QLearning wins - 283003, SI Agent wins - 140665, Draws - 6333
# Episode 431000: QLearning wins - 283666, SI Agent wins - 140990, Draws - 6345
# Episode 432000: QLearning wins - 284317, SI Agent wins - 141324, Draws - 6360
# Episode 433000: QLearning wins - 285015, SI Agent wins - 141612, Draws - 6374
# Episode 434000: QLearning wins - 285657, SI Agent wins - 141953, Draws - 6391
# Episode 435000: QLearning wins - 286325, SI Agent wins - 142269, Draws - 6407
# Episode 436000: QLearning wins - 286992, SI Agent wins - 142589, Draws - 6420
# Episode 437000: QLearning wins - 287633, SI Agent wins - 142938, Draws - 6430
# Episode 438000: QLearning wins - 288301, SI Agent wins - 143248, Draws - 6452
# Episode 439000: QLearning wins - 288982, SI Agent wins - 143558, Draws - 6461
# Episode 440000: QLearning wins - 289631, SI Agent wins - 143896, Draws - 6474
# Episode 441000: QLearning wins - 290323, SI Agent wins - 144189, Draws - 6489
# Episode 442000: QLearning wins - 290966, SI Agent wins - 144532, Draws - 6503
# Episode 443000: QLearning wins - 291642, SI Agent wins - 144842, Draws - 6517
# Episode 444000: QLearning wins - 292317, SI Agent wins - 145152, Draws - 6532
# Episode 445000: QLearning wins - 293001, SI Agent wins - 145457, Draws - 6543
# Episode 446000: QLearning wins - 293645, SI Agent wins - 145802, Draws - 6554
# Episode 447000: QLearning wins - 294279, SI Agent wins - 146145, Draws - 6577
# Episode 448000: QLearning wins - 294959, SI Agent wins - 146453, Draws - 6589
# Episode 449000: QLearning wins - 295631, SI Agent wins - 146767, Draws - 6603
# Episode 450000: QLearning wins - 296310, SI Agent wins - 147082, Draws - 6609
# Episode 451000: QLearning wins - 296962, SI Agent wins - 147420, Draws - 6619
# Episode 452000: QLearning wins - 297607, SI Agent wins - 147753, Draws - 6641
# Episode 453000: QLearning wins - 298274, SI Agent wins - 148074, Draws - 6653
# Episode 454000: QLearning wins - 298971, SI Agent wins - 148364, Draws - 6666
# Episode 455000: QLearning wins - 299636, SI Agent wins - 148683, Draws - 6682
# Episode 456000: QLearning wins - 300318, SI Agent wins - 148985, Draws - 6698
# Episode 457000: QLearning wins - 300994, SI Agent wins - 149292, Draws - 6715
# Episode 458000: QLearning wins - 301662, SI Agent wins - 149613, Draws - 6726
# Episode 459000: QLearning wins - 302311, SI Agent wins - 149945, Draws - 6745
# Episode 460000: QLearning wins - 302978, SI Agent wins - 150268, Draws - 6755
# Episode 461000: QLearning wins - 303640, SI Agent wins - 150589, Draws - 6772
# Episode 462000: QLearning wins - 304307, SI Agent wins - 150910, Draws - 6784
# Episode 463000: QLearning wins - 304963, SI Agent wins - 151234, Draws - 6804
# Episode 464000: QLearning wins - 305612, SI Agent wins - 151571, Draws - 6818
# Episode 465000: QLearning wins - 306266, SI Agent wins - 151907, Draws - 6828
# Episode 466000: QLearning wins - 306909, SI Agent wins - 152245, Draws - 6847
# Episode 467000: QLearning wins - 307558, SI Agent wins - 152581, Draws - 6862
# Episode 468000: QLearning wins - 308211, SI Agent wins - 152909, Draws - 6881
# Episode 469000: QLearning wins - 308877, SI Agent wins - 153231, Draws - 6893
# Episode 470000: QLearning wins - 309552, SI Agent wins - 153543, Draws - 6906
# Episode 471000: QLearning wins - 310216, SI Agent wins - 153869, Draws - 6916
# Episode 472000: QLearning wins - 310868, SI Agent wins - 154205, Draws - 6928
# Episode 473000: QLearning wins - 311519, SI Agent wins - 154541, Draws - 6941
# Episode 474000: QLearning wins - 312179, SI Agent wins - 154865, Draws - 6957
# Episode 475000: QLearning wins - 312843, SI Agent wins - 155185, Draws - 6973
# Episode 476000: QLearning wins - 313483, SI Agent wins - 155535, Draws - 6983
# Episode 477000: QLearning wins - 314160, SI Agent wins - 155843, Draws - 6998
# Episode 478000: QLearning wins - 314818, SI Agent wins - 156158, Draws - 7025
# Episode 479000: QLearning wins - 315450, SI Agent wins - 156509, Draws - 7042
# Episode 480000: QLearning wins - 316094, SI Agent wins - 156849, Draws - 7058
# Episode 481000: QLearning wins - 316759, SI Agent wins - 157169, Draws - 7073
# Episode 482000: QLearning wins - 317408, SI Agent wins - 157502, Draws - 7091
# Episode 483000: QLearning wins - 318079, SI Agent wins - 157817, Draws - 7105
# Episode 484000: QLearning wins - 318710, SI Agent wins - 158164, Draws - 7127
# Episode 485000: QLearning wins - 319372, SI Agent wins - 158486, Draws - 7143
# Episode 486000: QLearning wins - 320020, SI Agent wins - 158828, Draws - 7153
# Episode 487000: QLearning wins - 320695, SI Agent wins - 159141, Draws - 7165
# Episode 488000: QLearning wins - 321352, SI Agent wins - 159470, Draws - 7179
# Episode 489000: QLearning wins - 321991, SI Agent wins - 159813, Draws - 7197
# Episode 490000: QLearning wins - 322676, SI Agent wins - 160115, Draws - 7210
# Episode 491000: QLearning wins - 323348, SI Agent wins - 160421, Draws - 7232
# Episode 492000: QLearning wins - 324005, SI Agent wins - 160751, Draws - 7245
# Episode 493000: QLearning wins - 324665, SI Agent wins - 161078, Draws - 7258
# Episode 494000: QLearning wins - 325312, SI Agent wins - 161421, Draws - 7268
# Episode 495000: QLearning wins - 325957, SI Agent wins - 161762, Draws - 7282
# Episode 496000: QLearning wins - 326607, SI Agent wins - 162093, Draws - 7301
# Episode 497000: QLearning wins - 327263, SI Agent wins - 162415, Draws - 7323
# Episode 498000: QLearning wins - 327915, SI Agent wins - 162747, Draws - 7339
# Episode 499000: QLearning wins - 328561, SI Agent wins - 163088, Draws - 7352
# QLearning wins: 329223
# SI Agent wins: 163409
# Draws: 7368
# Total Episodes: 500000
